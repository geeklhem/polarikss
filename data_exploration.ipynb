# %%
import numpy as np
import pandas 
import matplotlib.pyplot as plt
# %matplotlib inline
# %cd data/
# Out:
# /home/guilhem/projects/polarity/data

# %%
apar = pandas.read_table("aPAR.txt",header=None)
print apar.shape
apar.head()
plt.imshow(apar.values)
plt.xlabel("distance (um)")
plt.ylabel("time (sec)")
# Out:
# (76, 65)

# %%
flow = pandas.read_table("flow-myosin-um-per-min.txt",header=None)
print flow.shape
flow.head()
plt.imshow(flow.values)
plt.xlabel("distance (um)")
plt.ylabel("time (sec)")
# Out:
# (76, 65)

# %%
ppar = pandas.read_table("pPAR.txt",header=None)
print ppar.shape
ppar.head()
plt.imshow(ppar.values)
plt.xlabel("distance (um)")
plt.ylabel("time (sec)")
# Out:
# (76, 65)

# %%
tsec = pandas.read_table("T-sec.txt",header=None)
print tsec.shape
tsec.head()
plt.plot(np.transpose(tsec.values))
# Out:
# (1, 751)

# %%
xum =	pandas.read_table("X-um.txt",header=None)
print xum.shape
xum.head()
plt.plot(np.transpose(xum.values))
# Out:
# (1, 65)
